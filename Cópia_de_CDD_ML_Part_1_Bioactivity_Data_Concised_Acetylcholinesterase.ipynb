# %% [markdown]
# <a href="https://colab.research.google.com/github/beatriz1692/beatriz1692/blob/main/C%C3%B3pia_de_CDD_ML_Part_1_Bioactivity_Data_Concised_Acetylcholinesterase.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Bioinformatics Project - Computational Drug Discovery [Part 1] Download Bioactivity Data (Concised version)**
#
# Chanin Nantasenamat
#
# [*'Data Professor' YouTube channel*](http://youtube.com/dataprofessor)
#
# In this Jupyter notebook, we will be building a real-life **data science project** that you can include in your **data science portfolio**. Particularly, we will be building a machine learning model using the ChEMBL bioactivity data.
#
# In **Part 1**, we will be performing Data Collection and Pre-Processing from the ChEMBL Database.
#
# Note for this Concised Version:
# * Redundant code cells were deleted.
# * Code cells for saving files to Google Drive has been deleted.
#
# ---

# %% [markdown]
# ## **ChEMBL Database**
#
# The [*ChEMBL Database*](https://www.ebi.ac.uk/chembl/) is a database that contains curated bioactivity data of more than 2 million compounds. It is compiled from more than 76,000 documents, 1.2 million assays and the data spans 13,000 targets and 1,800 cells and 33,000 indications.
# [Data as of March 25, 2020; ChEMBL version 26].

# %% [markdown]
# ## **Installing libraries**

# %% [markdown]
# Install the ChEMBL web service package so that we can retrieve bioactivity data from the ChEMBL Database.

# %%
! pip install chembl_webresource_client
# Out:
# Collecting chembl_webresource_client
#   Downloading https://files.pythonhosted.org/packages/2e/48/0db29040c92726fcc6f99a5bc89e0ea8cf5a9d84753ebaaf53108792da2a/chembl-webresource-client-0.10.2.tar.gz (51kB)
#      |████████████████████████████████| 61kB 2.1MB/s
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.6/dist-packages (from chembl_webresource_client) (1.24.3)
# Requirement already satisfied: requests>=2.18.4 in /usr/local/lib/python3.6/dist-packages (from chembl_webresource_client) (2.23.0)
# Collecting requests-cache>=0.4.7
#   Downloading https://files.pythonhosted.org/packages/7f/55/9b1c40eb83c16d8fc79c5f6c2ffade04208b080670fbfc35e0a5effb5a92/requests_cache-0.5.2-py2.py3-none-any.whl
# Requirement already satisfied: easydict in /usr/local/lib/python3.6/dist-packages (from chembl_webresource_client) (1.9)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests>=2.18.4->chembl_webresource_client) (2.9)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests>=2.18.4->chembl_webresource_client) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests>=2.18.4->chembl_webresource_client) (2020.4.5.1)
# Building wheels for collected packages: chembl-webresource-client
#   Building wheel for chembl-webresource-client (setup.py) ... done
#   Created wheel for chembl-webresource-client: filename=chembl_webresource_client-0.10.2-cp36-none-any.whl size=55661 sha256=a52d78c7928723755f476d68cdfcd640830e02a8ab2d24d68d28e0d0df1dcf8d
#   Stored in directory: /root/.cache/pip/wheels/e6/96/19/3f042bfda7c669bfe24c8278477f57b0fbbf3e488b4c09e3a8
# Successfully built chembl-webresource-client
# Installing collected packages: requests-cache, chembl-webresource-client
# Successfully installed chembl-webresource-client-0.10.2 requests-cache-0.5.2

# %% [markdown]
# ## **Importing libraries**

# %%
# Import necessary libraries
import pandas as pd
from chembl_webresource_client.new_client import new_client

# %% [markdown]
# ## **Search for Target protein**

# %% [markdown]
# ### **Target search for Acetylcholinesterase**

# %%
# Target search for coronavirus
target = new_client.target
target_query = target.search('coronavirus')
targets = pd.DataFrame.from_dict(target_query)
targets
# Out:
#   cross_references                                           organism  \
# 0               []                                        Coronavirus
# 1               []                                 Feline coronavirus
# 2               []                                 Murine coronavirus
# 3               []                                 Canine coronavirus
# 4               []                             Human coronavirus 229E
# 5               []                             Human coronavirus OC43
# 6               []  Severe acute respiratory syndrome-related coro...
# 7               []  Middle East respiratory syndrome-related coron...
# 8               []  Severe acute respiratory syndrome-related coro...
# 9               []    Severe acute respiratory syndrome coronavirus 2
#
#                                            pref_name  score  \
# 0                                        Coronavirus   17.0
# 1                                 Feline coronavirus   14.0
# 2                                 Murine coronavirus   14.0
# 3                                 Canine coronavirus   14.0
# 4                             Human coronavirus 229E   13.0
# 5                             Human coronavirus OC43   13.0
# 6                SARS coronavirus 3C-like proteinase   10.0
# 7  Middle East respiratory syndrome-related coron...    9.0
# 8                          Replicase polyprotein 1ab    4.0
# 9                          Replicase polyprotein 1ab    4.0
#
#    species_group_flag target_chembl_id  \
# 0               False     CHEMBL613732
# 1               False     CHEMBL612744
# 2               False    CHEMBL5209664
# 3               False    CHEMBL5291668
# 4               False     CHEMBL613837
# 5               False    CHEMBL5209665
# 6               False       CHEMBL3927
# 7               False    CHEMBL4296578
# 8               False       CHEMBL5118
# 9               False    CHEMBL4523582
#
#                                    target_components     target_type   tax_id
# 0                                                 []        ORGANISM    11119
# 1                                                 []        ORGANISM    12663
# 2                                                 []        ORGANISM   694005
# 3                                                 []        ORGANISM    11153
# 4                                                 []        ORGANISM    11137
# 5                                                 []        ORGANISM    31631
# 6  [{'accession': 'P0C6U8', 'component_descriptio...  SINGLE PROTEIN   694009
# 7                                                 []        ORGANISM  1335626
# 8  [{'accession': 'P0C6X7', 'component_descriptio...  SINGLE PROTEIN   694009
# 9  [{'accession': 'P0DTD1', 'component_descriptio...  SINGLE PROTEIN  2697049

# %% [markdown]
# ### **Select and retrieve bioactivity data for *Human Acetylcholinesterase* (first entry)**

# %% [markdown]
# We will assign the fifth entry (which corresponds to the target protein, *Human Acetylcholinesterase*) to the ***selected_target*** variable

# %%
selected_target = targets.target_chembl_id[6]
selected_target
# Out:
# 'CHEMBL3927'

# %% [markdown]
# Here, we will retrieve only bioactivity data for *Human Acetylcholinesterase* (CHEMBL220) that are reported as pChEMBL values.

# %%
activity = new_client.activity
res = activity.filter(target_chembl_id=selected_target).filter(standard_type="IC50")

# %%
df = pd.DataFrame.from_dict(res)

# %%
df.head(3)
# Out:
#   action_type activity_comment  activity_id activity_properties  \
# 0        None             None      1480935                  []
# 1        None             None      1480936                  []
# 2        None             None      1481061                  []
#
#   assay_chembl_id                                  assay_description  \
# 0    CHEMBL829584  In vitro inhibitory concentration against SARS...
# 1    CHEMBL829584  In vitro inhibitory concentration against SARS...
# 2    CHEMBL830868  In vitro inhibitory concentration against SARS...
#
#   assay_type assay_variant_accession assay_variant_mutation bao_endpoint  ...  \
# 0          B                    None                   None  BAO_0000190  ...
# 1          B                    None                   None  BAO_0000190  ...
# 2          B                    None                   None  BAO_0000190  ...
#
#                                      target_organism  \
# 0  Severe acute respiratory syndrome-related coro...
# 1  Severe acute respiratory syndrome-related coro...
# 2  Severe acute respiratory syndrome-related coro...
#
#                       target_pref_name target_tax_id text_value  toid  type  \
# 0  SARS coronavirus 3C-like proteinase        694009       None  None  IC50
# 1  SARS coronavirus 3C-like proteinase        694009       None  None  IC50
# 2  SARS coronavirus 3C-like proteinase        694009       None  None  IC50
#
#   units    uo_units upper_value value
# 0    uM  UO_0000065        None   7.2
# 1    uM  UO_0000065        None   9.4
# 2    uM  UO_0000065        None  13.5
#
# [3 rows x 46 columns]

# %%
df.standard_type.unique()
# Out:
# array(['IC50'], dtype=object)

# %% [markdown]
# Finally we will save the resulting bioactivity data to a CSV file **bioactivity_data.csv**.

# %%
df.to_csv('bioactivity_data.csv', index=False)

# %% [markdown]
# Copying files to google drive

# %%
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)
# Out:
# Mounted at /content/gdrive

# %%
! mkdir "/content/gdrive/My Drive/data"

# %%
! ls "/content/gdrive/My Drive/"
# Out:
# '101 Dos  Donts of UI Design [UI Pedia Bonus] (Pixsel Academy) (Z-Library) (1).pdf'
# '101 Dos  Donts of UI Design [UI Pedia Bonus] (Pixsel Academy) (Z-Library).pdf'
#  20240305_054738.mp4
#  410809895-Data-Science-do-zero-Primeiras-regras-pdf.pdf
# 'AI-900 AZURE CURSO'
#  Apresentação-final-gp4.gslides
#  APRESENTAÇÃOFINAL.gslides
# 'BACHARELADO EM CIÊNCIA DA COMPUTAÇÃO.pdf'
# 'Beatriz Saraiva Toneloto_20240526_014401_0000.pdf'
#  Beatriz_Saraiva_Toneloto_desenvolvimentowebportfolio.gdoc
# 'Bioinformatics_ Algorithms, Coding, Data Science and -- Rob Botwright -- 2024 -- Independently Published -- 9781839386886 -- 894e57896ce73fb99c5a481b61918e17 -- Anna’s Archive.pdf'
#  CALCULO
# 'Casas estranhas -- Uketsu -- 2025 -- Intrínseca -- 973c5c4c7c5c5e92ef7d1f54d2948c70 -- Anna’s Archive.pdf'
#  Certificados
#  Codigo_Limpo_Completo_PT.pdf
# 'Coletanea Front-End - Uma Antologia da Comunidade Front End Brasileira - Casa do Codigo.pdf'
# 'Color Mood by Sprrrint.pdf'
# 'Como direcionar meus estudos para atuar como engen....gdoc'
# 'Como estudar para atuar como suporte técnico?.gdoc'
# 'Comptia Network+ N10-009 Exam Cram (Exam Cram (Pearson)) -- Emmett Dulaney -- 8, 2024 -- Pearson It Certification -- 9780135340837 -- 945080fe98ec1ae9ff6e426f5dab331a -- Anna’s Archive.pdf'
# 'Cópia de Computer Science College Major Modern Presentation.gslides'
# 'Crie um plano de estudos para eu estudar designer ....gdoc'
# 'Crie um roteiro de estudos para ui ux design.gdoc'
#  cs50_Guide_v25.pdf
# 'Curso TI '
# 'CV CC BeatrizST.pdf'
# 'DADOS_DA_EMPRESA_.docx (Infra).gdoc'
#  data
# 'Declaração Etnia.gdoc'
# 'De que formas um profissional formado em ciência d....gdoc'
# 'Design Thinking Handbook (Eli Woolery) (Z-Library).pdf'
# 'Documento sem título (1).gdoc'
# 'Documento sem título (2).gdoc'
# 'Documento sem título.gdoc'
# 'Don'\''t Eat the Mystery Meat! (Graveyard School, #1) -- Thacker, Nola -- Graveyard School -- 1, Toronto, New York, Ontario, 1994 -- Toronto ; New York_ -- 9780553482232 -- 42ed297ef662f5a13470eaca46ed3412 -- Anna’s Archive.pdf'
#  engenhariaSoftwareSommerville_240715_220615.pdf
# 'Entendendo Algoritmos - Um Guia Ilustrado Para Programadores e Outros Curiosos - Autor (Aditya Y. Bhargava) (1).pdf'
# 'Eu imagens profiles desenhos'
# 'Font Mood Chart by Sprrrint.pdf'
# 'Fragments of Horror (Junji Ito) (Junji Ito) (z-lib.org)_cópia.pdf'
# 'Frontend Unicorn Learn code faster, be more efficient, become a high-valued developer and earn more money ( etc.) (Z-Library) (1).pdf'
# 'Frontend Unicorn Learn code faster, be more efficient, become a high-valued developer and earn more money ( etc.) (Z-Library).pdf'
#  fundamentos-da-matematica-elementar-1-.pdf
# 'Fundamentos matemáticos para a ciência da computação - Judith L Gersting.pdf'
#  Glicoses_medições_fevereiro2025.xlsx
# 'Guia Prático do Servidor Linux Administração Linux para Iniciantes (Juliano Ramos) (Z-Library) (1).pdf'
# 'Guia Prático do Servidor Linux Administração Linux para Iniciantes (Juliano Ramos) (Z-Library).pdf'
#  HEMPORA
# 'Imagens estranhas -- Uketsu -- 2025 -- Suma -- 96dbb719d917f361425e85f4a05028a7 -- Anna’s Archive.pdf'
#  IMG-20230705-WA0116.jpg
# 'Introdução à Programação com Python - Nilo Ney Coutinho Menezes.pdf'
# 'JavaScript O Guia Definitivo.pdf'
# 'Landing Page Hot Tips. Strengthen your Landing Pages with 100 design, development and conversion tips (Rob Hope) (Z-Library).pdf'
# 'Machine Learning in Bioinformatics of Protein Sequences_ -- Łukasz Kurgan -- S_l, 2022 -- World Scientific Publishing Co Pte Ltd -- 9789811258572 -- 306f40de6cecb27f4c693dc9cd6d6cb4 -- Anna’s Archive.pdf'
# "Mastering Python for bioinformatics _ how to write flexible, -- Ken Youens-Clark -- 1st edition, 2021 -- O'Reilly Media, Incorporated -- 9781098100858 -- b60bc8f12d7866ac9b399af89a674040 -- Anna’s.pdf"
# 'Me dê ideias de projetos com cada um dos tópicos c....gdoc'
#  Modelo_TCC_1_2.docx
# 'Módulo 1 - Aula 1.gdoc'
# 'Módulo 1 - Aula 2.gdoc'
# 'O que eu preciso estudar para conseguir fazer esse....gdoc'
# "Peruca's coffee shop"
# 'Planilha sem título (1).gsheet'
# 'Planilha sem título (2).gsheet'
# 'Planilha sem título.gsheet'
# 'Portfolio Beatriz'
# 'Pré-Cálculo. Uma Preparação Para o Cálculo (Sheldon Axler) (Z-Library) (1) (1).pdf'
# 'Pré-Cálculo. Uma Preparação Para o Cálculo (Sheldon Axler) (Z-Library) (1).pdf'
# 'Programação Estruturada'
# 'Projetos de ciência de dados com Python -- Stephen Klosterman -- 2020 -- Novatec Editora -- ae2d1a793a7a1dcc62b2afacee082ef4 -- Anna’s Archive.pdf'
# 'Psychology of User [UI Pedia Bonus] (Pixsel Academy) (Z-Library).pdf'
# 'Python - Escreva seus primeiros programas.pdf'
# 'Quais são as principais atividades realizadas durante o teste de software e por que é crucial para o processo de desenvolvimento?.gdoc'
# 'Qual é o ciclo de vida do desenvolvimento de software e quais são as suas fases principais?.gdoc'
# 'Querido diário orário, as piores coisas da vida também são -- Benton, Jim -- 2021 -- São Paulo_ Editora Fundamento -- 9784412957817 -- 4ddeb01dd6896d20c2e65a9767b6f23a -- Anna’s Archive.pdf'
# 'Querido Diário Otário 8 - Não É Minha Culpa Se Eu Sei De -- por Jamie Kelly -- Querido diário otário -- #8, São Paulo, Brazil, 2009 -- São Paulo_ -- 9788576767183 -- a35af1e4a81c17e640ab959317abb07f -- Anna’s Archive.pdf'
# 'Raciocínio Lógico'
# 'Redes de Computadores 6a Edição -- Andrew Tanenbaum & Nick Feamster & David Wetherall -- 2021 -- Bookman e Pearson -- 9788582605615 -- 2d61624c80bf039c76fc4a9c9486db3d -- Anna’s Archive.pdf'
#  referenciacss.pdf
#  Roadmaps
#  ROADMAPS
#  slidesgo-desenvolvimento-de-aplicativo-para-aprimorar-a-eficiencia-das-equipes-de-enfermagem-20240524054236QK9e.pdf
#  toaz.info-memory-notebook-of-nursing-vol-pr_61fb978e9ae00029441908e21dd71dc4.pdf
#  trabalhodados.drawio
# 'Trabalho - Orientacoes e Descricao_cópia.pdf'
# 'UI Pedia - A Complete UI Design Guide (Pixsel Academy) (Z-Library) (1).pdf'
# 'UI Pedia - A Complete UI Design Guide (Pixsel Academy) (Z-Library).pdf'
# 'VID_20231031_213608235 (1).mp4'
#  VID_20231031_213608235.mp4
#  VID_20240106_194704501.mp4
# 'Web programming 1'
# 'Web UI Design for the Human Eye Principles of Visual Consistency (UX Pin) (Z-Library).pdf'
#  wepik-modern-curriculum-vitae-20240516001345WJx8.pdf
# 'What to do Next [UI Pedia Bonus] (Pixsel Academy) (Z-Library) (1).pdf'

# %%
! mkdir "/content/gdrive/My Drive/data2"

# %%
! cp bioactivity_data.csv "/content/gdrive/My Drive/data"

# %%
! ls -1 "/content/gdrive/My Drive/data"
# Out:
# bioactivity_data.csv

# %%
! ls
# Out:
# acetylcholinesterase_01_bioactivity_data_raw.csv  gdrive
# bioactivity_data.csv				  sample_data

# %%
! head bioactivity_data.csv
# Out:
# action_type,activity_comment,activity_id,activity_properties,assay_chembl_id,assay_description,assay_type,assay_variant_accession,assay_variant_mutation,bao_endpoint,bao_format,bao_label,canonical_smiles,data_validity_comment,data_validity_description,document_chembl_id,document_journal,document_year,ligand_efficiency,molecule_chembl_id,molecule_pref_name,parent_molecule_chembl_id,pchembl_value,potential_duplicate,qudt_units,record_id,relation,src_id,standard_flag,standard_relation,standard_text_value,standard_type,standard_units,standard_upper_value,standard_value,target_chembl_id,target_organism,target_pref_name,target_tax_id,text_value,toid,type,units,uo_units,upper_value,value
# ,,1480935,[],CHEMBL829584,In vitro inhibitory concentration against SARS coronavirus main protease (SARS CoV 3C-like protease),B,,,BAO_0000190,BAO_0000357,single protein format,Cc1noc(C)c1CN1C(=O)C(=O)c2cc(C#N)ccc21,,,CHEMBL1139624,Bioorg Med Chem Lett,2005,"{'bei': '18.28', 'le': '0.33', 'lle': '3.25', 'sei': '5.90'}",CHEMBL187579,,CHEMBL187579,5.14,0,http://www.openphacts.org/units/Nanomolar,384103,=,1,1,=,,IC50,nM,,7200.0,CHEMBL3927,Severe acute respiratory syndrome-related coronavirus,SARS coronavirus 3C-like proteinase,694009,,,IC50,uM,UO_0000065,,7.2
# ,,1480936,[],CHEMBL829584,In vitro inhibitory concentration against SARS coronavirus main protease (SARS CoV 3C-like protease),B,,,BAO_0000190,BAO_0000357,single protein format,O=C1C(=O)N(Cc2ccc(F)cc2Cl)c2ccc(I)cc21,,,CHEMBL1139624,Bioorg Med Chem Lett,2005,"{'bei': '12.10', 'le': '0.33', 'lle': '1.22', 'sei': '13.45'}",CHEMBL188487,,CHEMBL188487,5.03,0,http://www.openphacts.org/units/Nanomolar,383984,=,1,1,=,,IC50,nM,,9400.0,CHEMBL3927,Severe acute respiratory syndrome-related coronavirus,SARS coronavirus 3C-like proteinase,694009,,,IC50,uM,UO_0000065,,9.4
# ,,1481061,[],CHEMBL830868,In vitro inhibitory concentration against SARS coronavirus main protease (SARS CoV 3C-like protease) at 20 uM,B,,,BAO_0000190,BAO_0000357,single protein format,O=C1C(=O)N(CC2COc3ccccc3O2)c2ccc(I)cc21,,,CHEMBL1139624,Bioorg Med Chem Lett,2005,"{'bei': '11.56', 'le': '0.29', 'lle': '2.21', 'sei': '8.72'}",CHEMBL185698,,CHEMBL185698,4.87,0,http://www.openphacts.org/units/Nanomolar,384106,=,1,1,=,,IC50,nM,,13500.0,CHEMBL3927,Severe acute respiratory syndrome-related coronavirus,SARS coronavirus 3C-like proteinase,694009,,,IC50,uM,UO_0000065,,13.5
# ,,1481065,[],CHEMBL829584,In vitro inhibitory concentration against SARS coronavirus main protease (SARS CoV 3C-like protease),B,,,BAO_0000190,BAO_0000357,single protein format,O=C1C(=O)N(Cc2cc3ccccc3s2)c2ccccc21,,,CHEMBL1139624,Bioorg Med Chem Lett,2005,"{'bei': '16.64', 'le': '0.32', 'lle': '1.25', 'sei': '13.06'}",CHEMBL426082,,CHEMBL426082,4.88,0,http://www.openphacts.org/units/Nanomolar,384075,=,1,1,=,,IC50,nM,,13110.0,CHEMBL3927,Severe acute respiratory syndrome-related coronavirus,SARS coronavirus 3C-like proteinase,694009,,,IC50,uM,UO_0000065,,13.11
# ,,1481066,[],CHEMBL829584,In vitro inhibitory concentration against SARS coronavirus main protease (SARS CoV 3C-like protease),B,,,BAO_0000190,BAO_0000357,single protein format,O=C1C(=O)N(Cc2cc3ccccc3s2)c2c1cccc2[N+](=O)[O-],,,CHEMBL1139624,Bioorg Med Chem Lett,2005,"{'bei': '16.84', 'le': '0.32', 'lle': '2.16', 'sei': '7.08'}",CHEMBL187717,,CHEMBL187717,5.70,0,http://www.openphacts.org/units/Nanomolar,384234,=,1,1,=,,IC50,nM,,2000.0,CHEMBL3927,Severe acute respiratory syndrome-related coronavirus,SARS coronavirus 3C-like proteinase,694009,,,IC50,uM,UO_0000065,,2.0
# ,,1481068,[],CHEMBL828143,In vitro inhibitory concentration SARS coronavirus main protease (SARS CoV 3C-like protease) ,B,,,BAO_0000190,BAO_0000357,single protein format,O=C1C(=O)N(Cc2cc3ccccc3s2)c2c(Br)cccc21,,,CHEMBL1139624,Bioorg Med Chem Lett,2005,"{'bei': '16.14', 'le': '0.37', 'lle': '1.62', 'sei': '16.07'}",CHEMBL365134,,CHEMBL365134,6.01,0,http://www.openphacts.org/units/Nanomolar,384081,=,1,1,=,,IC50,nM,,980.0,CHEMBL3927,Severe acute respiratory syndrome-related coronavirus,SARS coronavirus 3C-like proteinase,694009,,,IC50,uM,UO_0000065,,0.98
# ,,1481088,[],CHEMBL829584,In vitro inhibitory concentration against SARS coronavirus main protease (SARS CoV 3C-like protease),B,,,BAO_0000190,BAO_0000357,single protein format,O=C1C(=O)N(Cc2cc3ccccc3s2)c2ccc(F)cc21,,,CHEMBL1139624,Bioorg Med Chem Lett,2005,"{'bei': '17.08', 'le': '0.33', 'lle': '1.55', 'sei': '14.22'}",CHEMBL187598,,CHEMBL187598,5.32,0,http://www.openphacts.org/units/Nanomolar,384303,=,1,1,=,,IC50,nM,,4820.0,CHEMBL3927,Severe acute respiratory syndrome-related coronavirus,SARS coronavirus 3C-like proteinase,694009,,,IC50,uM,UO_0000065,,4.82
# ,,1481089,[],CHEMBL829584,In vitro inhibitory concentration against SARS coronavirus main protease (SARS CoV 3C-like protease),B,,,BAO_0000190,BAO_0000357,single protein format,O=C1C(=O)N(Cc2cc3ccccc3s2)c2ccc(I)cc21,,,CHEMBL1139624,Bioorg Med Chem Lett,2005,"{'bei': '14.36', 'le': '0.37', 'lle': '1.78', 'sei': '16.11'}",CHEMBL190743,,CHEMBL190743,6.02,0,http://www.openphacts.org/units/Nanomolar,384329,=,1,1,=,,IC50,nM,,950.0,CHEMBL3927,Severe acute respiratory syndrome-related coronavirus,SARS coronavirus 3C-like proteinase,694009,,,IC50,uM,UO_0000065,,0.95
# ,,1481093,[],CHEMBL829584,In vitro inhibitory concentration against SARS coronavirus main protease (SARS CoV 3C-like protease),B,,,BAO_0000190,BAO_0000357,single protein format,O=C1C(=O)N(Cc2cc3ccccc3s2)c2cccc(Cl)c21,,,CHEMBL1139624,Bioorg Med Chem Lett,2005,"{'bei': '15.10', 'le': '0.31', 'lle': '0.67', 'sei': '13.24'}",CHEMBL365469,,CHEMBL365469,4.95,0,http://www.openphacts.org/units/Nanomolar,384283,=,1,1,=,,IC50,nM,,11200.0,CHEMBL3927,Severe acute respiratory syndrome-related coronavirus,SARS coronavirus 3C-like proteinase,694009,,,IC50,uM,UO_0000065,,11.2

# %% [markdown]
# ## **Handling missing data**
# If any compounds has missing value for the **standard_value** and **canonical_smiles** column then drop it.

# %%
df2 = df[df.standard_value.notna()]
df2 = df2[df.canonical_smiles.notna()]
df2
# Out:
# /tmp/ipython-input-65-3852201246.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df2 = df2[df.canonical_smiles.notna()]
#                                            action_type activity_comment  \
# 0                                                 None             None
# 1                                                 None             None
# 2                                                 None             None
# 3                                                 None             None
# 4                                                 None             None
# ..                                                 ...              ...
# 242  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 243  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 244  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 245  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 246  {'action_type': 'INHIBITOR', 'description': 'N...             None
#
#      activity_id                                activity_properties  \
# 0        1480935                                                 []
# 1        1480936                                                 []
# 2        1481061                                                 []
# 3        1481065                                                 []
# 4        1481066                                                 []
# ..           ...                                                ...
# 242     25516041  [{'comments': None, 'relation': '=', 'result_f...
# 243     25516042  [{'comments': None, 'relation': '=', 'result_f...
# 244     25516043  [{'comments': None, 'relation': '=', 'result_f...
# 245     25516044  [{'comments': None, 'relation': '=', 'result_f...
# 246     25516045  [{'comments': None, 'relation': '=', 'result_f...
#
#     assay_chembl_id                                  assay_description  \
# 0      CHEMBL829584  In vitro inhibitory concentration against SARS...
# 1      CHEMBL829584  In vitro inhibitory concentration against SARS...
# 2      CHEMBL830868  In vitro inhibitory concentration against SARS...
# 3      CHEMBL829584  In vitro inhibitory concentration against SARS...
# 4      CHEMBL829584  In vitro inhibitory concentration against SARS...
# ..              ...                                                ...
# 242   CHEMBL5336133  Inhibition of SARS-CoV N-terminal 6His-SUMO-ta...
# 243   CHEMBL5336133  Inhibition of SARS-CoV N-terminal 6His-SUMO-ta...
# 244   CHEMBL5336133  Inhibition of SARS-CoV N-terminal 6His-SUMO-ta...
# 245   CHEMBL5336133  Inhibition of SARS-CoV N-terminal 6His-SUMO-ta...
# 246   CHEMBL5336133  Inhibition of SARS-CoV N-terminal 6His-SUMO-ta...
#
#     assay_type assay_variant_accession assay_variant_mutation bao_endpoint  \
# 0            B                    None                   None  BAO_0000190
# 1            B                    None                   None  BAO_0000190
# 2            B                    None                   None  BAO_0000190
# 3            B                    None                   None  BAO_0000190
# 4            B                    None                   None  BAO_0000190
# ..         ...                     ...                    ...          ...
# 242          B                    None                   None  BAO_0000190
# 243          B                    None                   None  BAO_0000190
# 244          B                    None                   None  BAO_0000190
# 245          B                    None                   None  BAO_0000190
# 246          B                    None                   None  BAO_0000190
#
#      ...                                    target_organism  \
# 0    ...  Severe acute respiratory syndrome-related coro...
# 1    ...  Severe acute respiratory syndrome-related coro...
# 2    ...  Severe acute respiratory syndrome-related coro...
# 3    ...  Severe acute respiratory syndrome-related coro...
# 4    ...  Severe acute respiratory syndrome-related coro...
# ..   ...                                                ...
# 242  ...  Severe acute respiratory syndrome-related coro...
# 243  ...  Severe acute respiratory syndrome-related coro...
# 244  ...  Severe acute respiratory syndrome-related coro...
# 245  ...  Severe acute respiratory syndrome-related coro...
# 246  ...  Severe acute respiratory syndrome-related coro...
#
#                         target_pref_name target_tax_id text_value  toid  \
# 0    SARS coronavirus 3C-like proteinase        694009       None  None
# 1    SARS coronavirus 3C-like proteinase        694009       None  None
# 2    SARS coronavirus 3C-like proteinase        694009       None  None
# 3    SARS coronavirus 3C-like proteinase        694009       None  None
# 4    SARS coronavirus 3C-like proteinase        694009       None  None
# ..                                   ...           ...        ...   ...
# 242  SARS coronavirus 3C-like proteinase        694009       None  None
# 243  SARS coronavirus 3C-like proteinase        694009       None  None
# 244  SARS coronavirus 3C-like proteinase        694009       None  None
# 245  SARS coronavirus 3C-like proteinase        694009       None  None
# 246  SARS coronavirus 3C-like proteinase        694009       None  None
#
#       type units    uo_units upper_value  value
# 0     IC50    uM  UO_0000065        None    7.2
# 1     IC50    uM  UO_0000065        None    9.4
# 2     IC50    uM  UO_0000065        None   13.5
# 3     IC50    uM  UO_0000065        None  13.11
# 4     IC50    uM  UO_0000065        None    2.0
# ..     ...   ...         ...         ...    ...
# 242  pIC50  None  UO_0000065        None   6.42
# 243   IC50    uM  UO_0000065        None  0.165
# 244   IC50    uM  UO_0000065        None  0.161
# 245  pIC50  None  UO_0000065        None   6.78
# 246  pIC50  None  UO_0000065        None   6.79
#
# [245 rows x 46 columns]

# %%
len(df2.canonical_smiles.unique())
# Out:
# 184

# %%
df2_nr = df2.drop_duplicates(['canonical_smiles'])
df2_nr
# Out:
#      activity_comment  activity_id  ... upper_value value
# 0                None        33969  ...        None  0.75
# 1                None        37563  ...        None   0.1
# 2                None        37565  ...        None  50.0
# 3                None        38902  ...        None   0.3
# 4                None        41170  ...        None   0.8
# ...               ...          ...  ...         ...   ...
# 7019             None     18798884  ...        None  2.44
# 7020             None     18798885  ...        None  2.54
# 7021             None     18798886  ...        None  3.81
# 7022             None     18798887  ...        None  3.46
# 7023             None     18798888  ...        None  2.78
#
# [4695 rows x 43 columns]

# %% [markdown]
# ## **Data pre-processing of the bioactivity data**

# %% [markdown]
# ### **Combine the 3 columns (molecule_chembl_id,canonical_smiles,standard_value) and bioactivity_class into a DataFrame**

# %%
selection = ['molecule_chembl_id','canonical_smiles','standard_value']
df3 = df2_nr[selection]
df3
# Out:
#      molecule_chembl_id  ... standard_value
# 0          CHEMBL133897  ...          750.0
# 1          CHEMBL336398  ...          100.0
# 2          CHEMBL131588  ...        50000.0
# 3          CHEMBL130628  ...          300.0
# 4          CHEMBL130478  ...          800.0
# ...                 ...  ...            ...
# 7019      CHEMBL4293155  ...         2440.0
# 7020      CHEMBL4282558  ...         2540.0
# 7021      CHEMBL4281727  ...         3810.0
# 7022      CHEMBL4292349  ...         3460.0
# 7023      CHEMBL4278260  ...         2780.0
#
# [4695 rows x 3 columns]

# %% [markdown]
# Saves dataframe to CSV file

# %%
df3.to_csv('acetylcholinesterase_02_bioactivity_data_preprocessed.csv', index=False)

# %% [markdown]
# ### **Labeling compounds as either being active, inactive or intermediate**
# The bioactivity data is in the IC50 unit. Compounds having values of less than 1000 nM will be considered to be **active** while those greater than 10,000 nM will be considered to be **inactive**. As for those values in between 1,000 and 10,000 nM will be referred to as **intermediate**.

# %%
bioactivity_class = []
for i in df2.standard_value:
  if float(i) >= 10000:
    bioactivity_class.append("inactive")
  elif float(i) <= 1000:
    bioactivity_class.append("active")
  else:
    bioactivity_class.append("intermediate")

# %% [markdown]
# ## **Iterate the molecule_chambl_id to a list**

# %%
df2.molecule_chembl_id
# Out:
# 0       CHEMBL187579
# 1       CHEMBL188487
# 2       CHEMBL185698
# 3       CHEMBL426082
# 4       CHEMBL187717
#            ...
# 242    CHEMBL4590273
# 243    CHEMBL5436771
# 244    CHEMBL2365410
# 245    CHEMBL5436771
# 246    CHEMBL2365410
# Name: molecule_chembl_id, Length: 245, dtype: object

# %%
mol_cid = []
for i in df2.molecule_chembl_id:
  mol_cid.append(i)

# %%
mol_cid
# Out:
# ['CHEMBL187579',
#  'CHEMBL188487',
#  'CHEMBL185698',
#  'CHEMBL426082',
#  'CHEMBL187717',
#  'CHEMBL365134',
#  'CHEMBL187598',
#  'CHEMBL190743',
#  'CHEMBL365469',
#  'CHEMBL188983',
#  'CHEMBL191575',
#  'CHEMBL370923',
#  'CHEMBL194398',
#  'CHEMBL196635',
#  'CHEMBL209287',
#  'CHEMBL358279',
#  'CHEMBL348660',
#  'CHEMBL379727',
#  'CHEMBL210525',
#  'CHEMBL148483',
#  'CHEMBL383725',
#  'CHEMBL118596',
#  'CHEMBL208732',
#  'CHEMBL208732',
#  'CHEMBL210146',
#  'CHEMBL210146',
#  'CHEMBL207458',
#  'CHEMBL207458',
#  'CHEMBL207484',
#  'CHEMBL207484',
#  'CHEMBL207207',
#  'CHEMBL207207',
#  'CHEMBL210487',
#  'CHEMBL210487',
#  'CHEMBL380470',
#  'CHEMBL380470',
#  'CHEMBL210612',
#  'CHEMBL210612',
#  'CHEMBL209667',
#  'CHEMBL209667',
#  'CHEMBL210097',
#  'CHEMBL210097',
#  'CHEMBL378674',
#  'CHEMBL378674',
#  'CHEMBL210216',
#  'CHEMBL210216',
#  'CHEMBL210195',
#  'CHEMBL210195',
#  'CHEMBL210437',
#  'CHEMBL210437',
#  'CHEMBL378677',
#  'CHEMBL378677',
#  'CHEMBL210972',
#  'CHEMBL210972',
#  'CHEMBL210145',
#  'CHEMBL210145',
#  'CHEMBL377225',
#  'CHEMBL377225',
#  'CHEMBL210823',
#  'CHEMBL210823',
#  'CHEMBL207381',
#  'CHEMBL207381',
#  'CHEMBL210511',
#  'CHEMBL210511',
#  'CHEMBL210632',
#  'CHEMBL210632',
#  'CHEMBL210497',
#  'CHEMBL210497',
#  'CHEMBL208584',
#  'CHEMBL208584',
#  'CHEMBL208763',
#  'CHEMBL208763',
#  'CHEMBL209227',
#  'CHEMBL209227',
#  'CHEMBL210092',
#  'CHEMBL210092',
#  'CHEMBL377150',
#  'CHEMBL377150',
#  'CHEMBL212454',
#  'CHEMBL213581',
#  'CHEMBL380403',
#  'CHEMBL212504',
#  'CHEMBL211969',
#  'CHEMBL384739',
#  'CHEMBL215732',
#  'CHEMBL212240',
#  'CHEMBL377253',
#  'CHEMBL215397',
#  'CHEMBL378342',
#  'CHEMBL379642',
#  'CHEMBL427404',
#  'CHEMBL212190',
#  'CHEMBL378700',
#  'CHEMBL212019',
#  'CHEMBL212399',
#  'CHEMBL215733',
#  'CHEMBL375130',
#  'CHEMBL214372',
#  'CHEMBL212218',
#  'CHEMBL222840',
#  'CHEMBL222769',
#  'CHEMBL222735',
#  'CHEMBL222628',
#  'CHEMBL222893',
#  'CHEMBL225515',
#  'CHEMBL222234',
#  'CHEMBL426898',
#  'CHEMBL269277',
#  'CHEMBL1448',
#  'CHEMBL116438',
#  'CHEMBL395263',
#  'CHEMBL242011',
#  'CHEMBL431525',
#  'CHEMBL258787',
#  'CHEMBL2372143',
#  'CHEMBL259622',
#  'CHEMBL261189',
#  'CHEMBL265704',
#  'CHEMBL261402',
#  'CHEMBL258581',
#  'CHEMBL409422',
#  'CHEMBL2372143',
#  'CHEMBL2372143',
#  'CHEMBL2372143',
#  'CHEMBL2372143',
#  'CHEMBL2372143',
#  'CHEMBL523052',
#  'CHEMBL495231',
#  'CHEMBL468553',
#  'CHEMBL222234',
#  'CHEMBL1082811',
#  'CHEMBL1082812',
#  'CHEMBL1083123',
#  'CHEMBL1083124',
#  'CHEMBL1082714',
#  'CHEMBL1082715',
#  'CHEMBL327313',
#  'CHEMBL1083958',
#  'CHEMBL1083959',
#  'CHEMBL1083286',
#  'CHEMBL1082332',
#  'CHEMBL1086234',
#  'CHEMBL1082333',
#  'CHEMBL1082334',
#  'CHEMBL1084478',
#  'CHEMBL1084479',
#  'CHEMBL1084480',
#  'CHEMBL1084481',
#  'CHEMBL187266',
#  'CHEMBL215254',
#  'CHEMBL2146517',
#  'CHEMBL187460',
#  'CHEMBL363535',
#  'CHEMBL227075',
#  'CHEMBL45830',
#  'CHEMBL187266',
#  'CHEMBL215254',
#  'CHEMBL2146517',
#  'CHEMBL187460',
#  'CHEMBL363535',
#  'CHEMBL227075',
#  'CHEMBL45830',
#  'CHEMBL215254',
#  'CHEMBL187460',
#  'CHEMBL363535',
#  'CHEMBL227075',
#  'CHEMBL45830',
#  'CHEMBL187266',
#  'CHEMBL215254',
#  'CHEMBL2146517',
#  'CHEMBL187460',
#  'CHEMBL363535',
#  'CHEMBL227075',
#  'CHEMBL45830',
#  'CHEMBL18786',
#  'CHEMBL2311740',
#  'CHEMBL2311736',
#  'CHEMBL2311734',
#  'CHEMBL2311733',
#  'CHEMBL2311732',
#  'CHEMBL2311731',
#  'CHEMBL2311730',
#  'CHEMBL2311729',
#  'CHEMBL2311727',
#  'CHEMBL2311726',
#  'CHEMBL2311709',
#  'CHEMBL2311705',
#  'CHEMBL2311700',
#  'CHEMBL2311695',
#  'CHEMBL2311694',
#  'CHEMBL1405735',
#  'CHEMBL2311693',
#  'CHEMBL2311692',
#  'CHEMBL2311691',
#  'CHEMBL2397338',
#  'CHEMBL2402686',
#  'CHEMBL2402685',
#  'CHEMBL2402680',
#  'CHEMBL2402508',
#  'CHEMBL2402501',
#  'CHEMBL18786',
#  'CHEMBL1929019',
#  'CHEMBL2402692',
#  'CHEMBL2402691',
#  'CHEMBL406516',
#  'CHEMBL2442082',
#  'CHEMBL2442053',
#  'CHEMBL2442054',
#  'CHEMBL2442055',
#  'CHEMBL2442056',
#  'CHEMBL2442057',
#  'CHEMBL2442058',
#  'CHEMBL2442059',
#  'CHEMBL2442061',
#  'CHEMBL2442062',
#  'CHEMBL2442063',
#  'CHEMBL2442064',
#  'CHEMBL2442065',
#  'CHEMBL2442066',
#  'CHEMBL2442067',
#  'CHEMBL2442069',
#  'CHEMBL2442073',
#  'CHEMBL2442074',
#  'CHEMBL2442075',
#  'CHEMBL2442076',
#  'CHEMBL2442077',
#  'CHEMBL2442078',
#  'CHEMBL2442079',
#  'CHEMBL2440138',
#  'CHEMBL2442080',
#  'CHEMBL2311693',
#  'CHEMBL18786',
#  'CHEMBL2311692',
#  'CHEMBL2442081',
#  'CHEMBL4465864',
#  'CHEMBL4532437',
#  'CHEMBL4437284',
#  'CHEMBL4459894',
#  'CHEMBL18786',
#  'CHEMBL4590273',
#  'CHEMBL4590273',
#  'CHEMBL5436771',
#  'CHEMBL2365410',
#  'CHEMBL5436771',
#  'CHEMBL2365410']

# %% [markdown]
# # **Iterate canonical_smiles to a list**

# %%
canonical_smiles = []
for i in df2.canonical_smiles:
  canonical_smiles.append(i)

# %% [markdown]
# # *Alternative version*

# %%
selection = ['molecule_chembl_id','canonical_smiles','standard_value']
df3 = df2[selection]

# %%
df3
# Out:
#     molecule_chembl_id                                   canonical_smiles  \
# 0         CHEMBL187579             Cc1noc(C)c1CN1C(=O)C(=O)c2cc(C#N)ccc21
# 1         CHEMBL188487             O=C1C(=O)N(Cc2ccc(F)cc2Cl)c2ccc(I)cc21
# 2         CHEMBL185698            O=C1C(=O)N(CC2COc3ccccc3O2)c2ccc(I)cc21
# 3         CHEMBL426082                O=C1C(=O)N(Cc2cc3ccccc3s2)c2ccccc21
# 4         CHEMBL187717    O=C1C(=O)N(Cc2cc3ccccc3s2)c2c1cccc2[N+](=O)[O-]
# ..                 ...                                                ...
# 242      CHEMBL4590273                  Cc1cccc2nc(CSC(=S)NCc3cccnc3)cn12
# 243      CHEMBL5436771                           S=C([S-])NCc1cccnc1.[K+]
# 244      CHEMBL2365410  CC(C)C[C@H](NC(=O)OCc1ccccc1)C(=O)N[C@@H](CC1C...
# 245      CHEMBL5436771                           S=C([S-])NCc1cccnc1.[K+]
# 246      CHEMBL2365410  CC(C)C[C@H](NC(=O)OCc1ccccc1)C(=O)N[C@@H](CC1C...
#
#     standard_value
# 0           7200.0
# 1           9400.0
# 2          13500.0
# 3          13110.0
# 4           2000.0
# ..             ...
# 242         380.19
# 243          165.0
# 244          161.0
# 245         165.96
# 246         162.18
#
# [245 rows x 3 columns]

# %%
pd.concat([df3,pd.Series(bioactivity_class)], axis=1)
# Out:
#     molecule_chembl_id                                   canonical_smiles  \
# 0         CHEMBL187579             Cc1noc(C)c1CN1C(=O)C(=O)c2cc(C#N)ccc21
# 1         CHEMBL188487             O=C1C(=O)N(Cc2ccc(F)cc2Cl)c2ccc(I)cc21
# 2         CHEMBL185698            O=C1C(=O)N(CC2COc3ccccc3O2)c2ccc(I)cc21
# 3         CHEMBL426082                O=C1C(=O)N(Cc2cc3ccccc3s2)c2ccccc21
# 4         CHEMBL187717    O=C1C(=O)N(Cc2cc3ccccc3s2)c2c1cccc2[N+](=O)[O-]
# ..                 ...                                                ...
# 244      CHEMBL2365410  CC(C)C[C@H](NC(=O)OCc1ccccc1)C(=O)N[C@@H](CC1C...
# 245      CHEMBL5436771                           S=C([S-])NCc1cccnc1.[K+]
# 246      CHEMBL2365410  CC(C)C[C@H](NC(=O)OCc1ccccc1)C(=O)N[C@@H](CC1C...
# 220                NaN                                                NaN
# 222                NaN                                                NaN
#
#     standard_value             0
# 0           7200.0  intermediate
# 1           9400.0  intermediate
# 2          13500.0      inactive
# 3          13110.0      inactive
# 4           2000.0  intermediate
# ..             ...           ...
# 244          161.0        active
# 245         165.96           NaN
# 246         162.18           NaN
# 220            NaN      inactive
# 222            NaN  intermediate
#
# [247 rows x 4 columns]

# %% [markdown]
# # Combine the 4 lists into a **dataframe**

# %%
data_tuples = list(zip(mol_cid, canonical_smiles, bioactivity_class))
df5 = pd.DataFrame( data_tuples,  columns=['molecule_chembl_id', 'canonical_smiles', 'bioactivity_class'])

# %%
df3
# Out:
#     molecule_chembl_id                                   canonical_smiles  \
# 0         CHEMBL187579             Cc1noc(C)c1CN1C(=O)C(=O)c2cc(C#N)ccc21
# 1         CHEMBL188487             O=C1C(=O)N(Cc2ccc(F)cc2Cl)c2ccc(I)cc21
# 2         CHEMBL185698            O=C1C(=O)N(CC2COc3ccccc3O2)c2ccc(I)cc21
# 3         CHEMBL426082                O=C1C(=O)N(Cc2cc3ccccc3s2)c2ccccc21
# 4         CHEMBL187717    O=C1C(=O)N(Cc2cc3ccccc3s2)c2c1cccc2[N+](=O)[O-]
# ..                 ...                                                ...
# 242      CHEMBL4590273                  Cc1cccc2nc(CSC(=S)NCc3cccnc3)cn12
# 243      CHEMBL5436771                           S=C([S-])NCc1cccnc1.[K+]
# 244      CHEMBL2365410  CC(C)C[C@H](NC(=O)OCc1ccccc1)C(=O)N[C@@H](CC1C...
# 245      CHEMBL5436771                           S=C([S-])NCc1cccnc1.[K+]
# 246      CHEMBL2365410  CC(C)C[C@H](NC(=O)OCc1ccccc1)C(=O)N[C@@H](CC1C...
#
#     standard_value
# 0           7200.0
# 1           9400.0
# 2          13500.0
# 3          13110.0
# 4           2000.0
# ..             ...
# 242         380.19
# 243          165.0
# 244          161.0
# 245         165.96
# 246         162.18
#
# [245 rows x 3 columns]

# %% [markdown]
# Saves dataframe to CSV file

# %%
df3.to_csv('bioactivity_preprocessed_data.cvs', index=False)

# %%
! ls -1
# Out:
# acetylcholinesterase_01_bioactivity_data_raw.csv
# bioactivity_data.csv
# bioactivity_preprocessed_data.cvs
# gdrive
# sample_data
